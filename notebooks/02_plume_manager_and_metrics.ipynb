# %% [markdown]
# # Plume Manager and Metrics
#
# Use the standalone plume manager app for day-to-day packing, and use this notebook when you want to script archive creation or plume-metric experiments.

# %%
from pathlib import Path
import sys

repo_root = Path.cwd()
if repo_root.name == "notebooks":
    repo_root = repo_root.parent
src_path = repo_root / "src"
if str(src_path) not in sys.path:
    sys.path.insert(0, str(src_path))

from pld_workflow.plume_management import build_plume_archive_stem, pack_plume_directory, read_metadata_json
from pld_workflow.plume_metrics import PlumeMetrics

# Example placeholders:
# source_dir = repo_root / "path" / "to" / "plume_dataset"
# metadata = read_metadata_json(repo_root / "notebooks" / "sample_data" / "sample_record.json")
# archive_path = repo_root / "tmp" / f"{build_plume_archive_stem(source_dir, metadata)}.h5"
# result = pack_plume_directory(source_dir, archive_path, metadata=metadata)
# print(result)

PlumeMetrics
