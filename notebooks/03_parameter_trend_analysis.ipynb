# %% [markdown]
# # Parameter Trend Analysis
#
# This notebook demonstrates the independent JSON trend-analysis helpers. The analysis tools are intentionally separate from the recorder UI so they do not add weight to the most common workflow.

# %%
from pathlib import Path
import sys

repo_root = Path.cwd()
if repo_root.name == "notebooks":
    repo_root = repo_root.parent
src_path = repo_root / "src"
if str(src_path) not in sys.path:
    sys.path.insert(0, str(src_path))

from pld_workflow.analysis import build_parameter_trend, list_available_parameters

sample_root = repo_root / "notebooks" / "sample_data"
available = list_available_parameters([sample_root])
trend = build_parameter_trend([sample_root], parameter="Laser Energy (mJ)", section="target_1")

available, trend[["timestamp", "growth_id", "section", "parameter", "numeric_value"]]
