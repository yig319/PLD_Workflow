# %% [markdown]
# # Parameter Recorder Quickstart
#
# This notebook stays lightweight on purpose. The normal desktop workflow is still the dedicated app launcher, while this notebook only demonstrates the shared save/export helpers used by the recorder.

# %%
from pathlib import Path
import sys

repo_root = Path.cwd()
if repo_root.name == "notebooks":
    repo_root = repo_root.parent
src_path = repo_root / "src"
if str(src_path) not in sys.path:
    sys.path.insert(0, str(src_path))

from pld_workflow.parameter_export import build_default_file_stem

build_default_file_stem("PLD-2026-001", "Yichen", "04/02/2026")
